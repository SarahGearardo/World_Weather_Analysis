# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. Zip function
# will pack them as pairs.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=50ed9d25e12b04ab0a381a3de0e38929

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | ndele
# Processing Record 3 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 1 | rorvik
# Processing Record 5 of Set 1 | okhotsk
# Processing Record 6 of Set 1 | louis trichardt
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | banda aceh
# Processing Record 10 of Set 1 | narsaq
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | salalah
# Processing Record 13 of Set 1 | flin flon
# Processing Record 14 of Set 1 | mus
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | alugan
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | guozhen
# Processing Record 19 of Set 1 | oistins
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | pyapon
# Processing Record 22 of Set 1 | faya
# Processing Record 23 of Set 1 | tawang
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | libiaz
# Processing Record 26 of Set 1 | manokwari
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | davila
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | srednekolymsk
# Processing Record 33 of Set 1 | areia branca
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | barcelos
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | portel
# Processing Record 39 of Set 1 | victoria
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | vila
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | sarangani
# Processing Record 45 of Set 1 | meiktila
# Processing Record 46 of Set 1 | kagadi
# Processing Record 47 of Set 1 | fort frances
# Processing Record 48 of Set 1 | teguldet
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | semibratovo
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | bridlington
# Processing Record 7 of Set 2 | roebourne
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | touros
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 2 | bengkulu
# Processing Record 13 of Set 2 | arraial do cabo
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | wilmington
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | banjar
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | aklavik
# Processing Record 24 of Set 2 | kangaatsiaq
# Processing Record 25 of Set 2 | okha
# Processing Record 26 of Set 2 | korla
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | goure
# Processing Record 30 of Set 2 | loandjili
# Processing Record 31 of Set 2 | boa vista
# Processing Record 32 of Set 2 | bezhanitsy
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | mehamn
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | hammerfest
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | miri
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | bambous virieux
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | sikea
# City not found. Skipping...
# Processing Record 48 of Set 2 | wattegama
# Processing Record 49 of Set 2 | portree
# Processing Record 50 of Set 2 | cukai
# Processing Record 1 of Set 3 | hualmay
# Processing Record 2 of Set 3 | trinidad
# Processing Record 3 of Set 3 | sassandra
# Processing Record 4 of Set 3 | hofn
# Processing Record 5 of Set 3 | tangzhai
# Processing Record 6 of Set 3 | mahebourg
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | castro
# Processing Record 9 of Set 3 | richards bay
# Processing Record 10 of Set 3 | coquimbo
# Processing Record 11 of Set 3 | biak
# Processing Record 12 of Set 3 | itarema
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 3 | suao
# City not found. Skipping...
# Processing Record 16 of Set 3 | scottsburgh
# City not found. Skipping...
# Processing Record 17 of Set 3 | carlsbad
# Processing Record 18 of Set 3 | hervey bay
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | eureka
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | zhigansk
# Processing Record 24 of Set 3 | ribeira grande
# Processing Record 25 of Set 3 | araouane
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 3 | tabory
# Processing Record 29 of Set 3 | cherskiy
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | cascais
# Processing Record 32 of Set 3 | topolobampo
# Processing Record 33 of Set 3 | aranos
# Processing Record 34 of Set 3 | nemuro
# Processing Record 35 of Set 3 | kruisfontein
# Processing Record 36 of Set 3 | burnie
# Processing Record 37 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 3 | myitkyina
# Processing Record 39 of Set 3 | bairiki
# Processing Record 40 of Set 3 | san carlos de bariloche
# Processing Record 41 of Set 3 | qinhuangdao
# Processing Record 42 of Set 3 | vestmannaeyjar
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | adrar
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | mount isa
# Processing Record 50 of Set 3 | yenagoa
# Processing Record 1 of Set 4 | luanda
# Processing Record 2 of Set 4 | mecca
# Processing Record 3 of Set 4 | ust-nera
# Processing Record 4 of Set 4 | yar-sale
# Processing Record 5 of Set 4 | mar del plata
# Processing Record 6 of Set 4 | caucaia
# Processing Record 7 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 4 | rabo de peixe
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | cap malheureux
# Processing Record 11 of Set 4 | jaleswar
# Processing Record 12 of Set 4 | konakovo
# Processing Record 13 of Set 4 | katobu
# Processing Record 14 of Set 4 | montclair
# Processing Record 15 of Set 4 | envira
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | puerto escondido
# Processing Record 19 of Set 4 | lompoc
# Processing Record 20 of Set 4 | carndonagh
# Processing Record 21 of Set 4 | elk point
# Processing Record 22 of Set 4 | ngunguru
# Processing Record 23 of Set 4 | yulara
# Processing Record 24 of Set 4 | port moresby
# Processing Record 25 of Set 4 | kavieng
# Processing Record 26 of Set 4 | bayan
# Processing Record 27 of Set 4 | algiers
# Processing Record 28 of Set 4 | saint-pierre
# Processing Record 29 of Set 4 | marienburg
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | hobbs
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | rocha
# Processing Record 34 of Set 4 | turukhansk
# Processing Record 35 of Set 4 | mansa
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | zvishavane
# Processing Record 40 of Set 4 | las cruces
# Processing Record 41 of Set 4 | shubarshi
# Processing Record 42 of Set 4 | los algarrobos
# Processing Record 43 of Set 4 | maragogi
# Processing Record 44 of Set 4 | porto murtinho
# Processing Record 45 of Set 4 | sur
# Processing Record 46 of Set 4 | lavrentiya
# Processing Record 47 of Set 4 | kastornoye
# Processing Record 48 of Set 4 | upernavik
# Processing Record 49 of Set 4 | mocorito
# Processing Record 50 of Set 4 | sinnamary
# Processing Record 1 of Set 5 | hithadhoo
# Processing Record 2 of Set 5 | stornoway
# Processing Record 3 of Set 5 | waikuku
# Processing Record 4 of Set 5 | russell
# Processing Record 5 of Set 5 | murray
# Processing Record 6 of Set 5 | saint-philippe
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | ipubi
# Processing Record 9 of Set 5 | pio xii
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | port pirie
# Processing Record 12 of Set 5 | chuy
# Processing Record 13 of Set 5 | chara
# Processing Record 14 of Set 5 | san nicolas
# Processing Record 15 of Set 5 | tiruvottiyur
# City not found. Skipping...
# Processing Record 16 of Set 5 | dandong
# Processing Record 17 of Set 5 | lata
# Processing Record 18 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 5 | guajara-mirim
# City not found. Skipping...
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | tahe
# Processing Record 22 of Set 5 | san francisco
# Processing Record 23 of Set 5 | makakilo city
# Processing Record 24 of Set 5 | saint-ambroise
# Processing Record 25 of Set 5 | corinto
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | jamestown
# Processing Record 28 of Set 5 | buchanan
# Processing Record 29 of Set 5 | dingle
# Processing Record 30 of Set 5 | chicama
# Processing Record 31 of Set 5 | zhaoqing
# Processing Record 32 of Set 5 | mirante do paranapanema
# Processing Record 33 of Set 5 | saint anthony
# Processing Record 34 of Set 5 | cayenne
# Processing Record 35 of Set 5 | osku
# City not found. Skipping...
# Processing Record 36 of Set 5 | lixourion
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | pemba
# Processing Record 39 of Set 5 | souillac
# Processing Record 40 of Set 5 | pine bluff
# Processing Record 41 of Set 5 | daru
# Processing Record 42 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 5 | rawlins
# Processing Record 45 of Set 5 | kibre mengist
# Processing Record 46 of Set 5 | ulaanbaatar
# Processing Record 47 of Set 5 | krasnoarmeysk
# Processing Record 48 of Set 5 | ihosy
# Processing Record 49 of Set 5 | shimoda
# Processing Record 50 of Set 5 | lima
# Processing Record 1 of Set 6 | praia
# Processing Record 2 of Set 6 | ozernovskiy
# Processing Record 3 of Set 6 | yaan
# Processing Record 4 of Set 6 | santa isabel do rio negro
# Processing Record 5 of Set 6 | nizhniy bestyakh
# Processing Record 6 of Set 6 | victor harbor
# Processing Record 7 of Set 6 | fukue
# Processing Record 8 of Set 6 | abnub
# Processing Record 9 of Set 6 | marawi
# Processing Record 10 of Set 6 | bulungu
# Processing Record 11 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 6 | praya
# Processing Record 13 of Set 6 | ereymentau
# Processing Record 14 of Set 6 | cairns
# Processing Record 15 of Set 6 | juneau
# Processing Record 16 of Set 6 | goryachegorsk
# Processing Record 17 of Set 6 | mayo
# Processing Record 18 of Set 6 | issia
# Processing Record 19 of Set 6 | sorland
# Processing Record 20 of Set 6 | anadyr
# Processing Record 21 of Set 6 | nikolskoye
# Processing Record 22 of Set 6 | ekibastuz
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 6 | toulepleu
# City not found. Skipping...
# Processing Record 26 of Set 6 | belmonte
# Processing Record 27 of Set 6 | khandyga
# Processing Record 28 of Set 6 | bedele
# Processing Record 29 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 6 | praia da vitoria
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | iberia
# Processing Record 33 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 6 | asfi
# Processing Record 35 of Set 6 | pangnirtung
# Processing Record 36 of Set 6 | shellbrook
# Processing Record 37 of Set 6 | tiksi
# Processing Record 38 of Set 6 | bathsheba
# Processing Record 39 of Set 6 | kennewick
# Processing Record 40 of Set 6 | xiongzhou
# Processing Record 41 of Set 6 | torbay
# Processing Record 42 of Set 6 | utete
# Processing Record 43 of Set 6 | alyangula
# Processing Record 44 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 6 | vyyezdnoye
# Processing Record 47 of Set 6 | denpasar
# Processing Record 48 of Set 6 | beringovskiy
# Processing Record 49 of Set 6 | rock sound
# Processing Record 50 of Set 6 | lebu
# Processing Record 1 of Set 7 | bolshoye selo
# Processing Record 2 of Set 7 | challans
# Processing Record 3 of Set 7 | darlowo
# Processing Record 4 of Set 7 | mitu
# Processing Record 5 of Set 7 | grand gaube
# Processing Record 6 of Set 7 | yeniseysk
# Processing Record 7 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 7 | deputatskiy
# Processing Record 9 of Set 7 | monjas
# Processing Record 10 of Set 7 | nederland
# Processing Record 11 of Set 7 | caravelas
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | barranca
# Processing Record 14 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 7 | saskylakh
# Processing Record 16 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 7 | port lincoln
# Processing Record 18 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 19 of Set 7 | kyela
# Processing Record 20 of Set 7 | ponorogo
# Processing Record 21 of Set 7 | vila velha
# Processing Record 22 of Set 7 | tura
# Processing Record 23 of Set 7 | rawson
# Processing Record 24 of Set 7 | namwala
# Processing Record 25 of Set 7 | longview
# Processing Record 26 of Set 7 | colares
# Processing Record 27 of Set 7 | poiana mare
# Processing Record 28 of Set 7 | beyneu
# Processing Record 29 of Set 7 | flinders
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | imbituba
# Processing Record 32 of Set 7 | ilulissat
# Processing Record 33 of Set 7 | christchurch
# Processing Record 34 of Set 7 | marsabit
# Processing Record 35 of Set 7 | palmer
# Processing Record 36 of Set 7 | port macquarie
# Processing Record 37 of Set 7 | saldanha
# Processing Record 38 of Set 7 | manacapuru
# Processing Record 39 of Set 7 | mao
# Processing Record 40 of Set 7 | garowe
# Processing Record 41 of Set 7 | roald
# Processing Record 42 of Set 7 | jiuquan
# Processing Record 43 of Set 7 | iquitos
# Processing Record 44 of Set 7 | zyrardow
# Processing Record 45 of Set 7 | talcahuano
# Processing Record 46 of Set 7 | gijon
# Processing Record 47 of Set 7 | dukat
# Processing Record 48 of Set 7 | markova
# Processing Record 49 of Set 7 | portobelo
# Processing Record 50 of Set 7 | iralaya
# Processing Record 1 of Set 8 | kununurra
# Processing Record 2 of Set 8 | powell river
# Processing Record 3 of Set 8 | ivanteyevka
# Processing Record 4 of Set 8 | boa esperanca
# Processing Record 5 of Set 8 | huangchuan
# Processing Record 6 of Set 8 | vytegra
# Processing Record 7 of Set 8 | margate
# Processing Record 8 of Set 8 | keighley
# Processing Record 9 of Set 8 | tsuyama
# Processing Record 10 of Set 8 | coihaique
# Processing Record 11 of Set 8 | shimanovsk
# Processing Record 12 of Set 8 | tiznit
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | nagato
# Processing Record 15 of Set 8 | maltahohe
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | pevek
# Processing Record 18 of Set 8 | saint-georges
# Processing Record 19 of Set 8 | simplicio mendes
# Processing Record 20 of Set 8 | wencheng
# Processing Record 21 of Set 8 | tripoli
# Processing Record 22 of Set 8 | severo-yeniseyskiy
# Processing Record 23 of Set 8 | lasa
# Processing Record 24 of Set 8 | yakeshi
# Processing Record 25 of Set 8 | norrtalje
# Processing Record 26 of Set 8 | opuwo
# Processing Record 27 of Set 8 | ruy barbosa
# Processing Record 28 of Set 8 | hirado
# Processing Record 29 of Set 8 | port keats
# Processing Record 30 of Set 8 | broken hill
# Processing Record 31 of Set 8 | aleksandrov gay
# Processing Record 32 of Set 8 | rokytne
# Processing Record 33 of Set 8 | antsohihy
# Processing Record 34 of Set 8 | bundaberg
# Processing Record 35 of Set 8 | husavik
# Processing Record 36 of Set 8 | dunedin
# Processing Record 37 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 38 of Set 8 | nurobod
# Processing Record 39 of Set 8 | puerto ayacucho
# Processing Record 40 of Set 8 | tanout
# Processing Record 41 of Set 8 | abu dhabi
# Processing Record 42 of Set 8 | ahipara
# Processing Record 43 of Set 8 | sao felix do xingu
# Processing Record 44 of Set 8 | aljezur
# Processing Record 45 of Set 8 | tuatapere
# Processing Record 46 of Set 8 | rameswaram
# Processing Record 47 of Set 8 | mount gambier
# Processing Record 48 of Set 8 | sabang
# Processing Record 49 of Set 8 | bukama
# Processing Record 50 of Set 8 | sao luis de montes belos
# Processing Record 1 of Set 9 | shingu
# Processing Record 2 of Set 9 | san jeronimo
# Processing Record 3 of Set 9 | mlimba
# Processing Record 4 of Set 9 | norman wells
# Processing Record 5 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 9 | labuhan
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 9 of Set 9 | mombetsu
# Processing Record 10 of Set 9 | tessalit
# Processing Record 11 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 9 | moissala
# Processing Record 13 of Set 9 | sorong
# Processing Record 14 of Set 9 | waipawa
# Processing Record 15 of Set 9 | konya
# Processing Record 16 of Set 9 | galveston
# Processing Record 17 of Set 9 | moindou
# Processing Record 18 of Set 9 | tomigusuku
# Processing Record 19 of Set 9 | kupang
# Processing Record 20 of Set 9 | benin
# Processing Record 21 of Set 9 | lugovoy
# Processing Record 22 of Set 9 | arkhangelsk
# Processing Record 23 of Set 9 | nenjiang
# Processing Record 24 of Set 9 | ilukste
# Processing Record 25 of Set 9 | santa maria del oro
# Processing Record 26 of Set 9 | port hedland
# Processing Record 27 of Set 9 | taoudenni
# Processing Record 28 of Set 9 | saint george
# Processing Record 29 of Set 9 | palana
# Processing Record 30 of Set 9 | tanda
# Processing Record 31 of Set 9 | yuancheng
# Processing Record 32 of Set 9 | esperance
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | wellsford
# Processing Record 35 of Set 9 | bajil
# Processing Record 36 of Set 9 | abu samrah
# Processing Record 37 of Set 9 | cockburn town
# Processing Record 38 of Set 9 | kachiry
# Processing Record 39 of Set 9 | valjala
# City not found. Skipping...
# Processing Record 40 of Set 9 | bhakkar
# Processing Record 41 of Set 9 | grindavik
# Processing Record 42 of Set 9 | lorengau
# Processing Record 43 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 9 | arlit
# Processing Record 45 of Set 9 | qaqortoq
# Processing Record 46 of Set 9 | aripuana
# Processing Record 47 of Set 9 | segovia
# Processing Record 48 of Set 9 | lagoa
# Processing Record 49 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 50 of Set 9 | hay river
# Processing Record 1 of Set 10 | wukari
# Processing Record 2 of Set 10 | beira
# Processing Record 3 of Set 10 | tarauaca
# Processing Record 4 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 5 of Set 10 | kerman
# Processing Record 6 of Set 10 | eyl
# Processing Record 7 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 10 | tommot
# Processing Record 9 of Set 10 | havre
# Processing Record 10 of Set 10 | manicore
# Processing Record 11 of Set 10 | tocopilla
# Processing Record 12 of Set 10 | hudson bay
# Processing Record 13 of Set 10 | sistranda
# Processing Record 14 of Set 10 | barabinsk
# Processing Record 15 of Set 10 | saint-andre
# Processing Record 16 of Set 10 | igarka
# Processing Record 17 of Set 10 | udarnyy
# Processing Record 18 of Set 10 | pangody
# Processing Record 19 of Set 10 | zarand
# Processing Record 20 of Set 10 | manzil salim
# Processing Record 21 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 10 | porto novo
# Processing Record 23 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 24 of Set 10 | winslow
# Processing Record 25 of Set 10 | codrington
# Processing Record 26 of Set 10 | namie
# Processing Record 27 of Set 10 | hamilton
# Processing Record 28 of Set 10 | grandview
# Processing Record 29 of Set 10 | ikom
# Processing Record 30 of Set 10 | walvis bay
# Processing Record 31 of Set 10 | ayan
# Processing Record 32 of Set 10 | oranjemund
# Processing Record 33 of Set 10 | idaho falls
# Processing Record 34 of Set 10 | kota kinabalu
# Processing Record 35 of Set 10 | akyab
# Processing Record 36 of Set 10 | cravo norte
# Processing Record 37 of Set 10 | te anau
# Processing Record 38 of Set 10 | alexandria
# Processing Record 39 of Set 10 | longyearbyen
# Processing Record 40 of Set 10 | brae
# Processing Record 41 of Set 10 | santa cruz cabralia
# Processing Record 42 of Set 10 | velizh
# Processing Record 43 of Set 10 | tres palos
# Processing Record 44 of Set 10 | aanekoski
# Processing Record 45 of Set 10 | saint-augustin
# Processing Record 46 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 10 | tautira
# Processing Record 48 of Set 10 | vostok
# Processing Record 49 of Set 10 | zalantun
# Processing Record 50 of Set 10 | paamiut
# Processing Record 1 of Set 11 | trairi
# Processing Record 2 of Set 11 | jubbal
# Processing Record 3 of Set 11 | boddam
# Processing Record 4 of Set 11 | presidente bernardes
# Processing Record 5 of Set 11 | pasni
# Processing Record 6 of Set 11 | lac du bonnet
# Processing Record 7 of Set 11 | makat
# Processing Record 8 of Set 11 | yerbogachen
# Processing Record 9 of Set 11 | losone
# Processing Record 10 of Set 11 | am timan
# Processing Record 11 of Set 11 | guerrero negro
# Processing Record 12 of Set 11 | roma
# Processing Record 13 of Set 11 | poronaysk
# Processing Record 14 of Set 11 | agbor
# Processing Record 15 of Set 11 | los andes
# Processing Record 16 of Set 11 | boguchany
# Processing Record 17 of Set 11 | tayoltita
# Processing Record 18 of Set 11 | andenes
# Processing Record 19 of Set 11 | eckernforde
# Processing Record 20 of Set 11 | salinas
# Processing Record 21 of Set 11 | mahon
# Processing Record 22 of Set 11 | kirkwood
# Processing Record 23 of Set 11 | launceston
# Processing Record 24 of Set 11 | nybro
# Processing Record 25 of Set 11 | alofi
# Processing Record 26 of Set 11 | puerto leguizamo
# Processing Record 27 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 11 | teguise
# Processing Record 29 of Set 11 | ocean city
# Processing Record 30 of Set 11 | yangjiang
# Processing Record 31 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 11 | duzce
# Processing Record 33 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 11 | tabursuq
# Processing Record 35 of Set 11 | mpika
# Processing Record 36 of Set 11 | matagami
# Processing Record 37 of Set 11 | arshan
# Processing Record 38 of Set 11 | havelock
# Processing Record 39 of Set 11 | samarai
# Processing Record 40 of Set 11 | beloha
# Processing Record 41 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 42 of Set 11 | prince rupert
# Processing Record 43 of Set 11 | robe
# Processing Record 44 of Set 11 | bandarbeyla
# Processing Record 45 of Set 11 | fonte boa
# Processing Record 46 of Set 11 | finschhafen
# Processing Record 47 of Set 11 | la romana
# Processing Record 48 of Set 11 | mantua
# Processing Record 49 of Set 11 | senador jose porfirio
# Processing Record 50 of Set 11 | changde
# Processing Record 1 of Set 12 | saint-francois
# Processing Record 2 of Set 12 | libertador general san martin
# Processing Record 3 of Set 12 | chapais
# Processing Record 4 of Set 12 | burica
# City not found. Skipping...
# Processing Record 5 of Set 12 | varnavino
# Processing Record 6 of Set 12 | whitehorse
# Processing Record 7 of Set 12 | lalibela
# Processing Record 8 of Set 12 | skibbereen
# Processing Record 9 of Set 12 | westport
# Processing Record 10 of Set 12 | tomatlan
# Processing Record 11 of Set 12 | carutapera
# Processing Record 12 of Set 12 | byron bay
# Processing Record 13 of Set 12 | varhaug
# Processing Record 14 of Set 12 | port hardy
# Processing Record 15 of Set 12 | marzuq
# Processing Record 16 of Set 12 | koumac
# Processing Record 17 of Set 12 | alice springs
# Processing Record 18 of Set 12 | marsh harbour
# Processing Record 19 of Set 12 | svetlogorsk
# Processing Record 20 of Set 12 | tarakan
# Processing Record 21 of Set 12 | laiyang
# Processing Record 22 of Set 12 | jinji
# Processing Record 23 of Set 12 | plouzane
# Processing Record 24 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 12 | ipeti
# City not found. Skipping...
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | waingapu
# Processing Record 28 of Set 12 | ijero
# Processing Record 29 of Set 12 | rapid valley
# Processing Record 30 of Set 12 | kunmadaras
# Processing Record 31 of Set 12 | kodinar
# Processing Record 32 of Set 12 | puro
# Processing Record 33 of Set 12 | svobodnyy
# Processing Record 34 of Set 12 | amvrosiyivka
# Processing Record 35 of Set 12 | sisimiut
# Processing Record 36 of Set 12 | asilah
# Processing Record 37 of Set 12 | ucluelet
# Processing Record 38 of Set 12 | alihe
# Processing Record 39 of Set 12 | nara
# Processing Record 40 of Set 12 | asau
# Processing Record 41 of Set 12 | porto walter
# Processing Record 42 of Set 12 | rochegda
# Processing Record 43 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 44 of Set 12 | manta
# Processing Record 45 of Set 12 | chengde
# Processing Record 46 of Set 12 | puerto suarez
# Processing Record 47 of Set 12 | fairbanks
# Processing Record 48 of Set 12 | bud
# Processing Record 49 of Set 12 | dwarka
# Processing Record 50 of Set 12 | tres arroyos
# Processing Record 1 of Set 13 | bourail
# Processing Record 2 of Set 13 | caibarien
# Processing Record 3 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 13 | wuwei
# Processing Record 5 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 13 | haysville
# Processing Record 7 of Set 13 | havoysund
# Processing Record 8 of Set 13 | dolinsk
# Processing Record 9 of Set 13 | inta
# Processing Record 10 of Set 13 | areosa
# Processing Record 11 of Set 13 | alekseyevsk
# Processing Record 12 of Set 13 | santa maria da vitoria
# Processing Record 13 of Set 13 | kamenka
# Processing Record 14 of Set 13 | liverpool
# Processing Record 15 of Set 13 | shakawe
# Processing Record 16 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 13 | haines junction
# Processing Record 18 of Set 13 | siguiri
# Processing Record 19 of Set 13 | madikeri
# Processing Record 20 of Set 13 | manga
# Processing Record 21 of Set 13 | pauini
# Processing Record 22 of Set 13 | manturovo
# Processing Record 23 of Set 13 | ixtapa
# Processing Record 24 of Set 13 | porbandar
# Processing Record 25 of Set 13 | goedereede
# Processing Record 26 of Set 13 | altea
# Processing Record 27 of Set 13 | cochabamba
# Processing Record 28 of Set 13 | wote
# Processing Record 29 of Set 13 | woodward
# Processing Record 30 of Set 13 | itoman
# Processing Record 31 of Set 13 | kawalu
# Processing Record 32 of Set 13 | diffa
# Processing Record 33 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 34 of Set 13 | solnechnyy
# Processing Record 35 of Set 13 | astaneh-ye ashrafiyeh
# Processing Record 36 of Set 13 | zyryanovsk
# Processing Record 37 of Set 13 | tsabong
# Processing Record 38 of Set 13 | san cristobal
# Processing Record 39 of Set 13 | port washington
# Processing Record 40 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 13 | chumikan
# Processing Record 43 of Set 13 | powell
# Processing Record 44 of Set 13 | estelle
# Processing Record 45 of Set 13 | bonavista
# Processing Record 46 of Set 13 | biltine
# Processing Record 47 of Set 13 | washougal
# Processing Record 48 of Set 13 | ogawara
# Processing Record 49 of Set 13 | uyuni
# Processing Record 50 of Set 13 | naze
# Processing Record 1 of Set 14 | sabzevar
# Processing Record 2 of Set 14 | labuan
# Processing Record 3 of Set 14 | ivankiv
# Processing Record 4 of Set 14 | timizart
# Processing Record 5 of Set 14 | zhangjiakou
# Processing Record 6 of Set 14 | balikpapan
# Processing Record 7 of Set 14 | kysyl-syr
# Processing Record 8 of Set 14 | tecolutla
# Processing Record 9 of Set 14 | darnah
# Processing Record 10 of Set 14 | birao
# Processing Record 11 of Set 14 | lagos
# Processing Record 12 of Set 14 | kaeo
# Processing Record 13 of Set 14 | butka
# Processing Record 14 of Set 14 | rio grande
# Processing Record 15 of Set 14 | maniitsoq
# Processing Record 16 of Set 14 | neftegorsk
# Processing Record 17 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 14 | dongsheng
# Processing Record 19 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 14 | karratha
# Processing Record 21 of Set 14 | tamandare
# Processing Record 22 of Set 14 | maceio
# Processing Record 23 of Set 14 | mopti
# Processing Record 24 of Set 14 | avera
# Processing Record 25 of Set 14 | port blair
# Processing Record 26 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 14 | balsas
# Processing Record 28 of Set 14 | kihei
# Processing Record 29 of Set 14 | abay
# Processing Record 30 of Set 14 | porto santo
# Processing Record 31 of Set 14 | zyryanka
# Processing Record 32 of Set 14 | albania
# Processing Record 33 of Set 14 | batticaloa
# Processing Record 34 of Set 14 | urumqi
# Processing Record 35 of Set 14 | vaitape
# Processing Record 36 of Set 14 | port augusta
# Processing Record 37 of Set 14 | progreso
# Processing Record 38 of Set 14 | havre-saint-pierre
# Processing Record 39 of Set 14 | nizhnevartovsk
# Processing Record 40 of Set 14 | val-david
# Processing Record 41 of Set 14 | san quintin
# Processing Record 42 of Set 14 | fomboni
# Processing Record 43 of Set 14 | tikrit
# Processing Record 44 of Set 14 | pishin
# Processing Record 45 of Set 14 | baiyin
# Processing Record 46 of Set 14 | menongue
# Processing Record 47 of Set 14 | moranbah
# Processing Record 48 of Set 14 | carupano
# Processing Record 49 of Set 14 | benguela
# Processing Record 50 of Set 14 | koyelga
# Processing Record 1 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 15 | hasaki
# Processing Record 3 of Set 15 | makhu
# Processing Record 4 of Set 15 | gamba
# Processing Record 5 of Set 15 | patancheru
# Processing Record 6 of Set 15 | kenai
# Processing Record 7 of Set 15 | safranbolu
# Processing Record 8 of Set 15 | pochutla
# Processing Record 9 of Set 15 | tongliao
# Processing Record 10 of Set 15 | ghazipur
# Processing Record 11 of Set 15 | belle glade
# Processing Record 12 of Set 15 | rafai
# Processing Record 13 of Set 15 | jawhar
# Processing Record 14 of Set 15 | udachnyy
# Processing Record 15 of Set 15 | cedar city
# Processing Record 16 of Set 15 | vernon
# Processing Record 17 of Set 15 | buala
# Processing Record 18 of Set 15 | melo
# Processing Record 19 of Set 15 | hurghada
# Processing Record 20 of Set 15 | imeni poliny osipenko
# Processing Record 21 of Set 15 | clarence town
# Processing Record 22 of Set 15 | san lorenzo
# Processing Record 23 of Set 15 | izhevskoye
# Processing Record 24 of Set 15 | ilebo
# Processing Record 25 of Set 15 | timberlake
# Processing Record 26 of Set 15 | jalalabad
# Processing Record 27 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 15 | komsomolskiy
# Processing Record 29 of Set 15 | nishihara
# Processing Record 30 of Set 15 | pemangkat
# Processing Record 31 of Set 15 | ambunti
# Processing Record 32 of Set 15 | kiruna
# Processing Record 33 of Set 15 | tulum
# Processing Record 34 of Set 15 | ozark
# Processing Record 35 of Set 15 | kousseri
# Processing Record 36 of Set 15 | tezu
# Processing Record 37 of Set 15 | henties bay
# Processing Record 38 of Set 15 | taitung
# Processing Record 39 of Set 15 | ekpoma
# Processing Record 40 of Set 15 | kuryk
# Processing Record 41 of Set 15 | seminole
# Processing Record 42 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 15 | nanakuli
# Processing Record 44 of Set 15 | san policarpo
# Processing Record 45 of Set 15 | phenix city
# Processing Record 46 of Set 15 | tandalti
# Processing Record 47 of Set 15 | nsanje
# Processing Record 48 of Set 15 | sibolga
# Processing Record 49 of Set 15 | ibra
# Processing Record 50 of Set 15 | tibati
# Processing Record 1 of Set 16 | viransehir
# Processing Record 2 of Set 16 | comodoro rivadavia
# Processing Record 3 of Set 16 | najran
# Processing Record 4 of Set 16 | langsa
# Processing Record 5 of Set 16 | bhinga
# Processing Record 6 of Set 16 | popondetta
# Processing Record 7 of Set 16 | vagur
# Processing Record 8 of Set 16 | aksaray
# Processing Record 9 of Set 16 | inhambane
# Processing Record 10 of Set 16 | uchaly
# Processing Record 11 of Set 16 | plettenberg bay
# Processing Record 12 of Set 16 | randolph
# Processing Record 13 of Set 16 | ahuimanu
# Processing Record 14 of Set 16 | diamantino
# Processing Record 15 of Set 16 | kletskaya
# Processing Record 16 of Set 16 | isangel
# Processing Record 17 of Set 16 | luebo
# Processing Record 18 of Set 16 | ust-tarka
# Processing Record 19 of Set 16 | faxinal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Clyde River      CA  70.4692  -68.5914      5.11        92          86
# 1            Ndele      CF   8.4109   20.6473     81.55        42          90
# 2           Rorvik      NO  64.8621   11.2373     33.91        75          75
# 3          Okhotsk      RU  59.3833  143.3000     15.21        93          93
# 4  Louis Trichardt      ZA -23.0439   29.9032     61.30        92          94
# 5       Bredasdorp      ZA -34.5322   20.0403     59.43        70          43
# 6     Punta Arenas      CL -53.1500  -70.9167     48.22        76           0
# 7       Banda Aceh      ID   5.5577   95.3222     79.50        79          77
# 8           Narsaq      GL  60.9167  -46.0500     35.82        78          43
# 9         Luderitz      NA -26.6481   15.1594     63.64        62           0
#
#    Wind Speed Current Description
# 0        2.17     overcast clouds
# 1        3.49     overcast clouds
# 2       20.71       broken clouds
# 3        6.80     overcast clouds
# 4       13.91     overcast clouds
# 5       16.40    scattered clouds
# 6       10.36           clear sky
# 7        4.18       broken clouds
# 8        3.80    scattered clouds
# 9       12.64           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weatherpy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
